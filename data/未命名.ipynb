# %%
import pandas as pd
import seaborn as sns
sns.set(style="darkgrid") ## 设置图的样式
sns.set(rc={'figure.figsize':(16,8)}) ## 图的大小

# %%
df = pd.DataFrame({'KNeighborsClassifier': {'Accuracy_score': 0.7325017739743008,
  'Precission_score': 0.708075962172187,
  'Recall_score': 0.7905030800821355,
  'F1-score': 0.7470226304342553,
  'auc': 0.7325458727650166},
 'RandomForestClassifier': {'Accuracy_score': 0.775068607921757,
  'Precission_score': 0.7559262091378322,
  'Recall_score': 0.8119609856262834,
  'F1-score': 0.7829422829422829,
  'auc': 0.7750966574494758},
 'LogisticRegression': {'Accuracy_score': 0.7530884251382846,
  'Precission_score': 0.7405713355579068,
  'Recall_score': 0.7785249828884325,
  'F1-score': 0.7590740354535974,
  'auc': 0.7531077647275458},
 'DecisionTreeClassifier': {'Accuracy_score': 0.7751284528379314,
  'Precission_score': 0.7566566038941333,
  'Recall_score': 0.8106091718001369,
  'F1-score': 0.7827042388493727,
  'auc': 0.7751554290718294},
 'AdaBoostClassifier': {'Accuracy_score': 0.7504296010053946,
  'Precission_score': 0.7441973082189494,
  'Recall_score': 0.7626112251882272,
  'F1-score': 0.7532917532917532,
  'auc': 0.7504388627777833}})

# %%
df
# Out:
#                   KNeighborsClassifier  RandomForestClassifier  \
# Accuracy_score                0.732502                0.775069
# Precission_score              0.708076                0.755926
# Recall_score                  0.790503                0.811961
# F1-score                      0.747023                0.782942
# auc                           0.732546                0.775097
#
#                   LogisticRegression  DecisionTreeClassifier  \
# Accuracy_score              0.753088                0.775128
# Precission_score            0.740571                0.756657
# Recall_score                0.778525                0.810609
# F1-score                    0.759074                0.782704
# auc                         0.753108                0.775155
#
#                   AdaBoostClassifier
# Accuracy_score              0.750430
# Precission_score            0.744197
# Recall_score                0.762611
# F1-score                    0.753292
# ...

# %%
df.T
# Out:
#                         Accuracy_score  Precission_score  Recall_score  \
# KNeighborsClassifier          0.732502          0.708076      0.790503
# RandomForestClassifier        0.775069          0.755926      0.811961
# LogisticRegression            0.753088          0.740571      0.778525
# DecisionTreeClassifier        0.775128          0.756657      0.810609
# AdaBoostClassifier            0.750430          0.744197      0.762611
#
#                         F1-score       auc
# KNeighborsClassifier    0.747023  0.732546
# RandomForestClassifier  0.782942  0.775097
# LogisticRegression      0.759074  0.753108
# DecisionTreeClassifier  0.782704  0.775155
# AdaBoostClassifier      0.753292  0.750439

# %%
# !pip3 install matplotlib
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the '/Users/andrew/django-vue-admin/venv/bin/python -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt

# %%
# plt.figure(figsize=(15,12))
plt.bar(df.T.index , df.T['Accuracy_score'],color=['r','g','b','r','g'])
plt.tick_params(labelsize=14)
plt.ylim(0.3,1.2)
# Out:
# (0.3, 1.2)

# %%
plt.figure(figsize=(15,12))
plt.bar(df.T.index , df.T['Precission_score'])
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(15,12))
plt.bar(df.T.index , df.T['Recall_score'])
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(15,12))
plt.bar(df.T.index , df.T['F1-score'])
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(15,16))
plt.bar(df.T.index , df.T['auc'])
plt.ylim(0,1.1)
plt.xlabel("classfier")
plt.ylabel('auc')
# plt.legend('auc')
plt.title("auc compare")
# Out:
# Text(0.5, 1.0, 'auc compare')
